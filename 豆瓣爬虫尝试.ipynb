# %% [markdown]
# ### 爬取豆瓣电视剧及其评分

# %% [markdown]
# ## 爬取豆瓣电影前250

# %%
import requests
from bs4 import BeautifulSoup
import urllib.request
import urllib

# %%
url="https://movie.douban.com/top250?"
dict_word={'start':0}
full_url=url+urllib.parse.urlencode(dict_word)
print(full_url)
# Out:
# https://movie.douban.com/top250?start=0

# %%
response = requests.get(full_url)
soup = BeautifulSoup(response.text,'lxml')

# %%
print(soup.contents)
# Out:
# ['html', <html class="" lang="zh-cmn-Hans">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="webkit" name="renderer"/>
# <meta content="always" name="referrer"/>
# <title>
# 豆瓣电影TOP250
# </title>
# <meta content="cZdR4xxR7RxmM4zE" name="baidu-site-verification"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Sun, 6 Mar 2005 01:00:00 GMT" http-equiv="Expires"/>
# <link href="https://img3.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="https://img3.doubanio.com/f/shire/bdb62d45fb145651da30ac3fec98f21c40cfc962/css/douban.css" rel="stylesheet" type="text/css"/>
# <link href="https://img3.doubanio.com/f/shire/905cdec30f13cd440e6f988dc5d2d99919f5a1d5/css/separation/_all.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">var _head_start = new Date();</script>
# ...

# %%
import re

# %%
# soup.findAll('span','title')
result=soup.find_all(attrs={"class": "title"})

# %%
result[0].string
# Out:
# '肖申克的救赎'

# %%
rating_result=soup.find_all(attrs={"class": "rating_num"})

# %%
rating_result[0].string
# Out:
# '9.6'

# %%
for i in result:
    title=str(i)[:-7][20:]
    if '/' in title :continue
    print(title)
# Out:
# 肖申克的救赎
# 这个杀手不太冷
# 阿甘正传
# 霸王别姬
# 美丽人生
# 千与千寻
# 辛德勒的名单
# 海上钢琴师
# 机器人总动员
# 盗梦空间
# 泰坦尼克号
# 三傻大闹宝莱坞
# 放牛班的春天
# 忠犬八公的故事
# 龙猫
# 大话西游之大圣娶亲
# 教父
# 乱世佳人
# 天堂电影院
# 当幸福来敲门
# 搏击俱乐部
# 楚门的世界
# 触不可及
# 指环王3：王者无敌
# 罗马假日

# %% [markdown]
# ### 正式程序

# %%
import requests
from bs4 import BeautifulSoup
import urllib.request
import urllib

url="https://movie.douban.com/top250?"
titleList=[]
ratingList=[]

for page in range(10):
    dict_word={'start':page*25}
    full_url=url+urllib.parse.urlencode(dict_word) #得到url
    response = requests.get(full_url)
    soup = BeautifulSoup(response.text,'lxml')
    result=soup.find_all(attrs={"class": "title"}) #得到title的list
    for i in result:
        title=i.string
        if '/' in title :continue
        titleList.append(title)
        
    rating_result=soup.find_all(attrs={"class": "rating_num"}) #得到rating的list
    for i in rating_result:
        rating=i.string
        ratingList.append(rating)
        
for i in range(len(ratingList)):
    print('Top'+str(i+1),titleList[i],ratingList[i])
# Out:
# Top1 肖申克的救赎 9.6
# Top2 这个杀手不太冷 9.4
# Top3 阿甘正传 9.4
# Top4 霸王别姬 9.4
# Top5 美丽人生 9.5
# Top6 千与千寻 9.2
# Top7 辛德勒的名单 9.4
# Top8 海上钢琴师 9.2
# Top9 机器人总动员 9.3
# Top10 盗梦空间 9.2
# Top11 泰坦尼克号 9.1
# Top12 三傻大闹宝莱坞 9.1
# Top13 放牛班的春天 9.2
# Top14 忠犬八公的故事 9.2
# Top15 龙猫 9.1
# Top16 大话西游之大圣娶亲 9.1
# Top17 教父 9.2
# Top18 乱世佳人 9.2
# Top19 天堂电影院 9.1
# Top20 当幸福来敲门 8.9
# Top21 搏击俱乐部 9.0
# Top22 楚门的世界 9.0
# Top23 触不可及 9.1
# Top24 指环王3：王者无敌 9.1
# Top25 罗马假日 8.9
# Top26 十二怒汉 9.3
# Top27 两杆大烟枪 9.0
# Top28 天空之城 9.0
# Top29 怦然心动 8.9
# Top30 海豚湾 9.3
# Top31 飞屋环游记 8.9
# Top32 大话西游之月光宝盒 8.9
# Top33 飞越疯人院 9.0
# Top34 无间道 8.9
# Top35 鬼子来了 9.1
# Top36 窃听风暴 9.1
# Top37 少年派的奇幻漂流 9.0
# Top38 蝙蝠侠：黑暗骑士 8.9
# Top39 V字仇杀队 8.8
# Top40 熔炉 9.1
# Top41 闻香识女人 8.9
# Top42 天使爱美丽 8.7
# Top43 活着 9.0
# Top44 美丽心灵 8.9
# Top45 指环王1：魔戒再现 8.9
# Top46 指环王2：双塔奇兵 8.9
# Top47 教父2 9.1
# Top48 哈尔的移动城堡 8.8
# Top49 七宗罪 8.7
# Top50 情书 8.8
# Top51 勇敢的心 8.8
# Top52 剪刀手爱德华 8.7
# Top53 死亡诗社 8.9
# Top54 美国往事 9.1
# Top55 钢琴家 9.0
# Top56 致命魔术 8.8
# ...
